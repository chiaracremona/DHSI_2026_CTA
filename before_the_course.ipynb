# %% [markdown]
# # Before the Course
#
# Please execute all the cells below carefully to set up your environment.
# This will help us save time and go smoothly through the course :)

# %%
########################################################
#                                                      #
# Before the course — environment check and user setup #
#                                                      #
########################################################


# Please enter below your username, it will help us to track your progress and provide you with support during the course. 
# You can use any username you like, but we recommend using something that is easy to remember and unique (e.g., your first name or a nickname). 
USERNAME = 'ChiaraC'

from helpers.helpers import prepare_user
prepare_user(USERNAME)

# %%
import time
from progress.checkpoint import checkpoint
from helpers.helpers import check_environment, help_kernel

# %%
ready = check_environment()
if ready:
    print("Your setup is ready, you can start the course :)")
    checkpoint ('Setup', 1)
else:
    print ("\n\n!!!\nUnfortunately, something went wrong, please read the message below and try again.\nIn case of trouble contact us: jacek.bakowski@ijppan.pl / michal.wozniak@ijppan.pl\n\n")
    time.sleep(5)
    help_kernel()
# Out:
# Your current Python version is: 3.13 — This is fine :)
# ✓ Python version is OK
# Incorrect kernel: /home/michauw/miniconda3/envs/dh2026
# Your setup is ready, you can start the course :)
# ✅ Checkpoint 1 for session 'Setup' registered successfully!
